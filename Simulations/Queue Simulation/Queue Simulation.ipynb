# %% [markdown]
# # Simulation of a Queue using Discrete Event Simulation.
# # (Work in progress!!  Needs comments and improvement in the structure of the program. Also analysis of generated data required e.g. average waiting times. Also graphics to be added possibly).
# # David Brookes December 2020.

# %%
# Simulation of a queue.
# There is one teller who services one queue.

# %%
import numpy as np
np.random.seed(1)

import random
random.seed(11)

# %%
class State:
    def __init__(self, queue_len=0, teller_in_serv=False):
        self.queue_length = queue_len
        self.teller_in_service = teller_in_serv 
        # self.teller_break_time = teller_break_tim # The amount of time the teller is on a break from serving customers.
        self.waiting_time = [] # A list of waiting times for each person that has had to queue.
        
        
class Person:
    def __init__(self, start_wait = 0.0, end_wait = 0.0):
        self.start_waiting = start_wait
        self.end_waiting = end_wait

class Person_list:
    def __init__(self):
        self.person_list = []
        self.serve_index = 0 # The index of the next person to be served.
        
    def add_person(self, person):
        self.person_list.append(person)
        
#    def remove_person(self):
#        if self.person_list != []:
#            del self.person_list[0]

#    def print_list(self):
#        print('Printing the Person List...')
#        num_people = len(self.person_list)
#        for i in range(num_people):
#            print(self.person_list[i].start_waiting)
#            print(self.person_list[i].end_waiting)
#            print('')
            
    def print_list(self):
        print('Printing the Person List...')
        print('')
        for p in self.person_list:
            print(p.start_waiting)
            print(p.end_waiting)
            print('')
        if self.person_list == []:
            print('Person list is EMPTY') 
            print('')
    
    
class Event:
    """An event in the simulation."""
    # 'event_names' is a class attribute.
    event_names = ['Start', 'Customer_Arrival', 'Customer_Departure', 'Teller_Starts_Service', 'Teller_Ends_Service', 'End']
    
    def __init__(self, name, time):
        self.event_name = name
        self.event_time = time
        

# Set the parameters for the queuing model. (Experiment with different values!).

StartToEndTime = 100 # Time in seconds.

TellerStartsServiceTime_mu = 10 # Average time in seconds for a teller to start service (assuming normal distribution).
TellerStartsServiceTime_sd = 1  # The standard deviation of the normal distribution.

TellerServiceTime_mu = 30 # Average time in seconds for a teller to do a work session (assuming normal distribution).
TellerServiceTime_sd = 1   # The standard deviation of the normal distribution.

TellerBreakTime_mu = 10 # Average time in seconds for a teller to take a break (assuming normal distribution).
TellerBreakTime_sd = 1   # The standard deviation of the normal distribution.
        
CustomerArrivalTime_mu = 5 #  Average time in seconds for a customer arrival (assuming Poisson distribution).

CustomerServiceTime_mu = 4 #  Average time in seconds for a teller to serve a customer (assuming Poisson distribution).
    
class Events_list: 
    
    def __init__(self):
        self.event_list = []

#    def print_list(self):
#        print('Printing the Events List...')
#        num_events = len(self.event_list)
#        for i in range(num_events):
#            print(self.event_list[i].event_name)
#            print(self.event_list[i].event_time)
#            print('')
            
    def print_list(self):
        print('Printing the Events List...')
        print('')
        for e in self.event_list:
            print(e.event_name)
            print(e.event_time)
            print('')
        if self.event_list == []:
            print('Events list is EMPTY')  
            print('')

        
    def process_event(self):
        t0 = self.event_list[0].event_time
        e_name = self.event_list[0].event_name
        print('Processing (and deleting) the event -- ', e_name, '-- at time ', t0)
        
        if e_name == 'Start':
            
            # Create the first 'Customer_Arrival' event.
            t_customer_arrival = t0 + random.expovariate(1.0/CustomerArrivalTime_mu)
            e_customer_arrival = Event('Customer_Arrival', t_customer_arrival)
            self.insert_event(e_customer_arrival) 
            print('Schedule the event -- Customer_Arrival -- at time ', t_customer_arrival)
                 
            # Create a 'Teller_Starts_Service' event.
            t_teller_starts_service = t0 + np.random.normal(TellerStartsServiceTime_mu, TellerStartsServiceTime_sd)
            e_teller_starts_service = Event('Teller_Starts_Service', t_teller_starts_service)
            self.insert_event(e_teller_starts_service)
            print('Schedule the event -- Teller_Starts_Service -- at time ', t_teller_starts_service)
                  
            # Create an 'End' event.
            t_end = t0 + StartToEndTime
            e_end = Event('End', t_end)
            self.insert_event(e_end)
            print('Schedule the event -- End -- at time ', t_end)
                 
        elif  e_name == 'Customer_Arrival':
            # Increment the queue length.
            state.queue_length += 1
            print('Queue incremented to ', state.queue_length)

            # Create a Person and add the person to the Person list.            
            p = Person(t0) # Set start_waiting time to t0.
            
            print('Adding the new arrival to the person list...')
            p_list.add_person(p)
            p_list.print_list()
            
            # Create another 'Customer_Arrival' event.
            t_customer_arrival = t0 + random.expovariate(1.0/CustomerArrivalTime_mu)
            e_customer_arrival = Event('Customer_Arrival', t_customer_arrival)
            self.insert_event(e_customer_arrival) 
            print('Schedule the event -- Customer_Arrival -- at time ', t_customer_arrival)

            # Create a 'Customer_Departure' event if the Teller is serving and there is exactly one person in the queue.
            # (The departure time of a person joining an empty queue can be determined - statistically!).
            if state.teller_in_service == True and state.queue_length == 1:
                t_customer_departure = t0 + random.expovariate(1.0/CustomerServiceTime_mu)
                e_customer_departure = Event('Customer_Departure', t_customer_departure)
                self.insert_event(e_customer_departure) 
                print('Schedule the event -- Customer_Departure -- at time ', t_customer_departure)
            

            # PUT MORE CODE IN HERE WHEN state.teller_in_service == False???? No, I suspect!
                                 

        elif  e_name == 'Customer_Departure':
            if state.teller_in_service == True:
                if state.queue_length > 0:
                    print('state.teller_in_service', state.teller_in_service)
                    # Decrement the queue length.
                    state.queue_length -= 1
                    print('Queue decremented to ', state.queue_length)
                    # Process the next person from the Person list.

                    print ('For Person index ', p_list.serve_index ,'setting end_waiting time to ', t0)
                    p_list.person_list[p_list.serve_index].end_waiting = t0
                    #print('p_list.person_list[p_list.serve_index].start_waiting = ', p_list.person_list[p_list.serve_index].start_waiting)
                    #print('p_list.person_list[p_list.serve_index].end_waiting = ', p_list.person_list[p_list.serve_index].end_waiting)               
                    p_list.print_list()
                    # Increment the Serve_index (to service the next person in the queue).
                    p_list.serve_index += 1
                    # If there is still a queue of people then schedule the next departure event.
                    if state.queue_length > 0:
                        t_customer_departure = t0 + random.expovariate(1.0/CustomerServiceTime_mu)
                        e_customer_departure = Event('Customer_Departure', t_customer_departure)
                        self.insert_event(e_customer_departure) 
                        print('Schedule the event -- Customer_Departure -- at time ', t_customer_departure)
                
            # I DONT THINK THIS CODE BELOW IS NEEDED AT ALL!                   
            #else: # state.teller_in_service == False
                # The person will served by the teller at a delayed time determined by teller_break_time.
                # CHECK THIS!!!!!!
             #   print('state.teller_in_service', state.teller_in_service)
             #   e_customer_departure = Event('Customer_Departure', t0 + state.teller_break_time)
             #   self.insert_event(e_customer_departure)                
                
                

        
        elif  e_name == 'Teller_Starts_Service':
            state.teller_in_service = True   
            
            # Create a 'Customer_Departure' event if there is anyone in the queue.
            if state.queue_length > 0:
                t_customer_departure = t0 + random.expovariate(1.0/CustomerServiceTime_mu)
                e_customer_departure = Event('Customer_Departure', t_customer_departure)
                self.insert_event(e_customer_departure) 
                print('Schedule the event -- Customer_Departure -- at time ', t_customer_departure)
            
            # Create a 'Teller_Ends_Service' event.
            t_teller_ends_service = t0 + np.random.normal(TellerServiceTime_mu, TellerServiceTime_sd)
            e_teller_ends_service = Event('Teller_Ends_Service', t_teller_ends_service)
            self.insert_event(e_teller_ends_service)
            print('Schedule the event -- Teller_Ends_Service -- at time ', t_teller_ends_service)
        
        elif  e_name == 'Teller_Ends_Service':
            state.teller_in_service = False
            
            # Create a 'Teller_Starts_Service' event.
            t_teller_starts_service = t0 + np.random.normal(TellerBreakTime_mu, TellerBreakTime_sd)
            e_teller_starts_service = Event('Teller_Starts_Service', t_teller_starts_service)
            self.insert_event(e_teller_starts_service)  
            print('Schedule the event -- Teller_Starts_Service -- at time ', t_teller_starts_service)
                       
        if  e_name == 'End':    
            print('End of simulation')
            # Clear all the events list.
            self.event_list.clear() 
        else:
            # Delete the first event.
            # The event that has been processed is deleted from the events list in order to
            # to save computer memory. This is important for long simulations.
            del self.event_list[0]

    
    def insert_event(self, event):
        num_events = len(self.event_list)
        if num_events == 0:
            if event.event_time >= 0.0: # Want the time of the first event to be >=0.0 (start time will be set to 0.0).
                #print('appending an empty list')
                self.event_list.append(event)
        elif num_events == 1:
            if event.event_time >= self.event_list[0].event_time:
                #print('appending a list with one element in it')
                self.event_list.append(event)         
        else:
            before_first_event = False
            if event.event_time < self.event_list[0].event_time:
                before_first_event = True 
            #print('before_first_event', before_first_event)
            if not before_first_event:
                index = 1 # Start from 1 not 0. 
                inserted = False
                while index < num_events and inserted == False:
                    if event.event_time < self.event_list[index].event_time:
                        #print('insertion')
                        self.event_list.insert(index, event)
                        inserted = True
                    index = index + 1
                if inserted == False:
                    #print('appending')
                    self.event_list.append(event)    
                    
        
    def remove_event():
        pass

# %%
# Initialise the State of the system.
state = State()
#print('Initial queue length = ', state.queue_length)
#print('teller_in_service = ', state.teller_in_service)
#print('')

# Create a Person list (All of the people involved during the length of the simulation).
p_list = Person_list()

# Create an Events list.
e_list = Events_list()

# Add the Start event to the Events list.
# Create the first Event.
e_start = Event('Start', 0.0)
e_list.insert_event(e_start)
e_list.print_list()

# print('Into the WHILE loop....')
# print('')

while e_list.event_list != []:
    print('')
    e_list.process_event()
    e_list.print_list()
# Out:
# Printing the Events List...
#
# Start
# 0.0
#
#
# Processing (and deleting) the event --  Start -- at time  0.0
# Schedule the event -- Customer_Arrival -- at time  3.0108642394857497
# Schedule the event -- Teller_Starts_Service -- at time  11.624345363663242
# Schedule the event -- End -- at time  100.0
# Printing the Events List...
#
# Customer_Arrival
# 3.0108642394857497
#
# Teller_Starts_Service
# 11.624345363663242
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  3.0108642394857497
# Queue incremented to  1
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  7.113181146801232
# Printing the Events List...
#
# Customer_Arrival
# 7.113181146801232
#
# Teller_Starts_Service
# 11.624345363663242
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  7.113181146801232
# Queue incremented to  2
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 0.0
#
# 7.113181146801232
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  20.012164281816368
# Printing the Events List...
#
# Teller_Starts_Service
# 11.624345363663242
#
# Customer_Arrival
# 20.012164281816368
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Teller_Starts_Service -- at time  11.624345363663242
# Schedule the event -- Customer_Departure -- at time  14.131162784456201
# Schedule the event -- Teller_Ends_Service -- at time  41.01258895001317
# Printing the Events List...
#
# Customer_Departure
# 14.131162784456201
#
# Customer_Arrival
# 20.012164281816368
#
# Teller_Ends_Service
# 41.01258895001317
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  14.131162784456201
# state.teller_in_service True
# Queue decremented to  1
# For Person index  0 setting end_waiting time to  14.131162784456201
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 0.0
#
# Schedule the event -- Customer_Departure -- at time  16.966978779624206
# Printing the Events List...
#
# Customer_Departure
# 16.966978779624206
#
# Customer_Arrival
# 20.012164281816368
#
# Teller_Ends_Service
# 41.01258895001317
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  16.966978779624206
# state.teller_in_service True
# Queue decremented to  0
# For Person index  1 setting end_waiting time to  16.966978779624206
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# Printing the Events List...
#
# Customer_Arrival
# 20.012164281816368
#
# Teller_Ends_Service
# 41.01258895001317
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  20.012164281816368
# Queue incremented to  1
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  24.438363828761958
# Schedule the event -- Customer_Departure -- at time  20.828766268030975
# Printing the Events List...
#
# Customer_Departure
# 20.828766268030975
#
# Customer_Arrival
# 24.438363828761958
#
# Teller_Ends_Service
# 41.01258895001317
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  20.828766268030975
# state.teller_in_service True
# Queue decremented to  0
# For Person index  2 setting end_waiting time to  20.828766268030975
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# Printing the Events List...
#
# Customer_Arrival
# 24.438363828761958
#
# Teller_Ends_Service
# 41.01258895001317
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  24.438363828761958
# Queue incremented to  1
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  28.02462720662835
# Schedule the event -- Customer_Departure -- at time  28.414105233489874
# Printing the Events List...
#
# Customer_Arrival
# 28.02462720662835
#
# Customer_Departure
# 28.414105233489874
#
# Teller_Ends_Service
# 41.01258895001317
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  28.02462720662835
# Queue incremented to  2
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 0.0
#
# 28.02462720662835
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  35.89925103163339
# Printing the Events List...
#
# Customer_Departure
# 28.414105233489874
#
# Customer_Arrival
# 35.89925103163339
#
# Teller_Ends_Service
# 41.01258895001317
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  28.414105233489874
# state.teller_in_service True
# Queue decremented to  1
# For Person index  3 setting end_waiting time to  28.414105233489874
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 0.0
#
# Schedule the event -- Customer_Departure -- at time  28.809514223000914
# Printing the Events List...
#
# Customer_Departure
# 28.809514223000914
#
# Customer_Arrival
# 35.89925103163339
#
# Teller_Ends_Service
# 41.01258895001317
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  28.809514223000914
# state.teller_in_service True
# Queue decremented to  0
# For Person index  4 setting end_waiting time to  28.809514223000914
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# Printing the Events List...
#
# Customer_Arrival
# 35.89925103163339
#
# Teller_Ends_Service
# 41.01258895001317
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  35.89925103163339
# Queue incremented to  1
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  37.70697969965855
# Schedule the event -- Customer_Departure -- at time  36.27944225350741
# Printing the Events List...
#
# Customer_Departure
# 36.27944225350741
#
# Customer_Arrival
# 37.70697969965855
#
# Teller_Ends_Service
# 41.01258895001317
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  36.27944225350741
# state.teller_in_service True
# Queue decremented to  0
# For Person index  5 setting end_waiting time to  36.27944225350741
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# Printing the Events List...
#
# Customer_Arrival
# 37.70697969965855
#
# Teller_Ends_Service
# 41.01258895001317
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  37.70697969965855
# Queue incremented to  1
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  46.001290114512464
# Schedule the event -- Customer_Departure -- at time  42.43632703667886
# Printing the Events List...
#
# Teller_Ends_Service
# 41.01258895001317
#
# Customer_Departure
# 42.43632703667886
#
# Customer_Arrival
# 46.001290114512464
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Teller_Ends_Service -- at time  41.01258895001317
# Schedule the event -- Teller_Starts_Service -- at time  50.484417197749714
# Printing the Events List...
#
# Customer_Departure
# 42.43632703667886
#
# Customer_Arrival
# 46.001290114512464
#
# Teller_Starts_Service
# 50.484417197749714
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  42.43632703667886
# Printing the Events List...
#
# Customer_Arrival
# 46.001290114512464
#
# Teller_Starts_Service
# 50.484417197749714
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  46.001290114512464
# Queue incremented to  2
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 0.0
#
# 46.001290114512464
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  46.21520310935385
# Printing the Events List...
#
# Customer_Arrival
# 46.21520310935385
#
# Teller_Starts_Service
# 50.484417197749714
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  46.21520310935385
# Queue incremented to  3
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 0.0
#
# 46.001290114512464
# 0.0
#
# 46.21520310935385
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  66.35613946900312
# Printing the Events List...
#
# Teller_Starts_Service
# 50.484417197749714
#
# Customer_Arrival
# 66.35613946900312
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Teller_Starts_Service -- at time  50.484417197749714
# Schedule the event -- Customer_Departure -- at time  63.86645925871613
# Schedule the event -- Teller_Ends_Service -- at time  79.41144857559354
# Printing the Events List...
#
# Customer_Departure
# 63.86645925871613
#
# Customer_Arrival
# 66.35613946900312
#
# Teller_Ends_Service
# 79.41144857559354
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  63.86645925871613
# state.teller_in_service True
# Queue decremented to  2
# For Person index  6 setting end_waiting time to  63.86645925871613
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 0.0
#
# 46.21520310935385
# 0.0
#
# Schedule the event -- Customer_Departure -- at time  68.11082980857087
# Printing the Events List...
#
# Customer_Arrival
# 66.35613946900312
#
# Customer_Departure
# 68.11082980857087
#
# Teller_Ends_Service
# 79.41144857559354
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  66.35613946900312
# Queue incremented to  3
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 0.0
#
# 46.21520310935385
# 0.0
#
# 66.35613946900312
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  71.1360123898236
# Printing the Events List...
#
# Customer_Departure
# 68.11082980857087
#
# Customer_Arrival
# 71.1360123898236
#
# Teller_Ends_Service
# 79.41144857559354
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  68.11082980857087
# state.teller_in_service True
# Queue decremented to  2
# For Person index  7 setting end_waiting time to  68.11082980857087
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 0.0
#
# 66.35613946900312
# 0.0
#
# Schedule the event -- Customer_Departure -- at time  68.79632824074875
# Printing the Events List...
#
# Customer_Departure
# 68.79632824074875
#
# Customer_Arrival
# 71.1360123898236
#
# Teller_Ends_Service
# 79.41144857559354
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  68.79632824074875
# state.teller_in_service True
# Queue decremented to  1
# For Person index  8 setting end_waiting time to  68.79632824074875
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 0.0
#
# Schedule the event -- Customer_Departure -- at time  68.8567857846788
# Printing the Events List...
#
# Customer_Departure
# 68.8567857846788
#
# Customer_Arrival
# 71.1360123898236
#
# Teller_Ends_Service
# 79.41144857559354
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  68.8567857846788
# state.teller_in_service True
# Queue decremented to  0
# For Person index  9 setting end_waiting time to  68.8567857846788
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# Printing the Events List...
#
# Customer_Arrival
# 71.1360123898236
#
# Teller_Ends_Service
# 79.41144857559354
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  71.1360123898236
# Queue incremented to  1
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# 71.1360123898236
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  74.89393432545722
# Schedule the event -- Customer_Departure -- at time  71.38160426988357
# Printing the Events List...
#
# Customer_Departure
# 71.38160426988357
#
# Customer_Arrival
# 74.89393432545722
#
# Teller_Ends_Service
# 79.41144857559354
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  71.38160426988357
# state.teller_in_service True
# Queue decremented to  0
# For Person index  10 setting end_waiting time to  71.38160426988357
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# 71.1360123898236
# 71.38160426988357
#
# Printing the Events List...
#
# Customer_Arrival
# 74.89393432545722
#
# Teller_Ends_Service
# 79.41144857559354
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  74.89393432545722
# Queue incremented to  1
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# 71.1360123898236
# 71.38160426988357
#
# 74.89393432545722
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  75.94882522016029
# Schedule the event -- Customer_Departure -- at time  76.00192119067496
# Printing the Events List...
#
# Customer_Arrival
# 75.94882522016029
#
# Customer_Departure
# 76.00192119067496
#
# Teller_Ends_Service
# 79.41144857559354
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  75.94882522016029
# Queue incremented to  2
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# 71.1360123898236
# 71.38160426988357
#
# 74.89393432545722
# 0.0
#
# 75.94882522016029
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  76.10154699336196
# Printing the Events List...
#
# Customer_Departure
# 76.00192119067496
#
# Customer_Arrival
# 76.10154699336196
#
# Teller_Ends_Service
# 79.41144857559354
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  76.00192119067496
# state.teller_in_service True
# Queue decremented to  1
# For Person index  11 setting end_waiting time to  76.00192119067496
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# 71.1360123898236
# 71.38160426988357
#
# 74.89393432545722
# 76.00192119067496
#
# 75.94882522016029
# 0.0
#
# Schedule the event -- Customer_Departure -- at time  78.49591659687103
# Printing the Events List...
#
# Customer_Arrival
# 76.10154699336196
#
# Customer_Departure
# 78.49591659687103
#
# Teller_Ends_Service
# 79.41144857559354
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  76.10154699336196
# Queue incremented to  2
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# 71.1360123898236
# 71.38160426988357
#
# 74.89393432545722
# 76.00192119067496
#
# 75.94882522016029
# 0.0
#
# 76.10154699336196
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  79.00538383281898
# Printing the Events List...
#
# Customer_Departure
# 78.49591659687103
#
# Customer_Arrival
# 79.00538383281898
#
# Teller_Ends_Service
# 79.41144857559354
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  78.49591659687103
# state.teller_in_service True
# Queue decremented to  1
# For Person index  12 setting end_waiting time to  78.49591659687103
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# 71.1360123898236
# 71.38160426988357
#
# 74.89393432545722
# 76.00192119067496
#
# 75.94882522016029
# 78.49591659687103
#
# 76.10154699336196
# 0.0
#
# Schedule the event -- Customer_Departure -- at time  85.88738560345186
# Printing the Events List...
#
# Customer_Arrival
# 79.00538383281898
#
# Teller_Ends_Service
# 79.41144857559354
#
# Customer_Departure
# 85.88738560345186
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  79.00538383281898
# Queue incremented to  2
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# 71.1360123898236
# 71.38160426988357
#
# 74.89393432545722
# 76.00192119067496
#
# 75.94882522016029
# 78.49591659687103
#
# 76.10154699336196
# 0.0
#
# 79.00538383281898
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  82.66611421794721
# Printing the Events List...
#
# Teller_Ends_Service
# 79.41144857559354
#
# Customer_Arrival
# 82.66611421794721
#
# Customer_Departure
# 85.88738560345186
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Teller_Ends_Service -- at time  79.41144857559354
# Schedule the event -- Teller_Starts_Service -- at time  90.27685620491822
# Printing the Events List...
#
# Customer_Arrival
# 82.66611421794721
#
# Customer_Departure
# 85.88738560345186
#
# Teller_Starts_Service
# 90.27685620491822
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  82.66611421794721
# Queue incremented to  3
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# 71.1360123898236
# 71.38160426988357
#
# 74.89393432545722
# 76.00192119067496
#
# 75.94882522016029
# 78.49591659687103
#
# 76.10154699336196
# 0.0
#
# 79.00538383281898
# 0.0
#
# 82.66611421794721
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  87.77842359683615
# Printing the Events List...
#
# Customer_Departure
# 85.88738560345186
#
# Customer_Arrival
# 87.77842359683615
#
# Teller_Starts_Service
# 90.27685620491822
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  85.88738560345186
# Printing the Events List...
#
# Customer_Arrival
# 87.77842359683615
#
# Teller_Starts_Service
# 90.27685620491822
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  87.77842359683615
# Queue incremented to  4
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# 71.1360123898236
# 71.38160426988357
#
# 74.89393432545722
# 76.00192119067496
#
# 75.94882522016029
# 78.49591659687103
#
# 76.10154699336196
# 0.0
#
# 79.00538383281898
# 0.0
#
# 82.66611421794721
# 0.0
#
# 87.77842359683615
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  91.2418915361474
# Printing the Events List...
#
# Teller_Starts_Service
# 90.27685620491822
#
# Customer_Arrival
# 91.2418915361474
#
# End
# 100.0
#
#
# Processing (and deleting) the event --  Teller_Starts_Service -- at time  90.27685620491822
# Schedule the event -- Customer_Departure -- at time  94.62101718375489
# Schedule the event -- Teller_Ends_Service -- at time  117.97531750803793
# Printing the Events List...
#
# Customer_Arrival
# 91.2418915361474
#
# Customer_Departure
# 94.62101718375489
#
# End
# 100.0
#
# Teller_Ends_Service
# 117.97531750803793
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  91.2418915361474
# Queue incremented to  5
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# 71.1360123898236
# 71.38160426988357
#
# 74.89393432545722
# 76.00192119067496
#
# 75.94882522016029
# 78.49591659687103
#
# 76.10154699336196
# 0.0
#
# 79.00538383281898
# 0.0
#
# 82.66611421794721
# 0.0
#
# 87.77842359683615
# 0.0
#
# 91.2418915361474
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  94.29815983824348
# Printing the Events List...
#
# Customer_Arrival
# 94.29815983824348
#
# Customer_Departure
# 94.62101718375489
#
# End
# 100.0
#
# Teller_Ends_Service
# 117.97531750803793
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  94.29815983824348
# Queue incremented to  6
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# 71.1360123898236
# 71.38160426988357
#
# 74.89393432545722
# 76.00192119067496
#
# 75.94882522016029
# 78.49591659687103
#
# 76.10154699336196
# 0.0
#
# 79.00538383281898
# 0.0
#
# 82.66611421794721
# 0.0
#
# 87.77842359683615
# 0.0
#
# 91.2418915361474
# 0.0
#
# 94.29815983824348
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  95.92793877998913
# Printing the Events List...
#
# Customer_Departure
# 94.62101718375489
#
# Customer_Arrival
# 95.92793877998913
#
# End
# 100.0
#
# Teller_Ends_Service
# 117.97531750803793
#
#
# Processing (and deleting) the event --  Customer_Departure -- at time  94.62101718375489
# state.teller_in_service True
# Queue decremented to  5
# For Person index  13 setting end_waiting time to  94.62101718375489
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# 71.1360123898236
# 71.38160426988357
#
# 74.89393432545722
# 76.00192119067496
#
# 75.94882522016029
# 78.49591659687103
#
# 76.10154699336196
# 94.62101718375489
#
# 79.00538383281898
# 0.0
#
# 82.66611421794721
# 0.0
#
# 87.77842359683615
# 0.0
#
# 91.2418915361474
# 0.0
#
# 94.29815983824348
# 0.0
#
# Schedule the event -- Customer_Departure -- at time  118.8449449146278
# Printing the Events List...
#
# Customer_Arrival
# 95.92793877998913
#
# End
# 100.0
#
# Teller_Ends_Service
# 117.97531750803793
#
# Customer_Departure
# 118.8449449146278
#
#
# Processing (and deleting) the event --  Customer_Arrival -- at time  95.92793877998913
# Queue incremented to  6
# Adding the new arrival to the person list...
# Printing the Person List...
#
# 3.0108642394857497
# 14.131162784456201
#
# 7.113181146801232
# 16.966978779624206
#
# 20.012164281816368
# 20.828766268030975
#
# 24.438363828761958
# 28.414105233489874
#
# 28.02462720662835
# 28.809514223000914
#
# 35.89925103163339
# 36.27944225350741
#
# 37.70697969965855
# 63.86645925871613
#
# 46.001290114512464
# 68.11082980857087
#
# 46.21520310935385
# 68.79632824074875
#
# 66.35613946900312
# 68.8567857846788
#
# 71.1360123898236
# 71.38160426988357
#
# 74.89393432545722
# 76.00192119067496
#
# 75.94882522016029
# 78.49591659687103
#
# 76.10154699336196
# 94.62101718375489
#
# 79.00538383281898
# 0.0
#
# 82.66611421794721
# 0.0
#
# 87.77842359683615
# 0.0
#
# 91.2418915361474
# 0.0
#
# 94.29815983824348
# 0.0
#
# 95.92793877998913
# 0.0
#
# Schedule the event -- Customer_Arrival -- at time  123.16393049066453
# Printing the Events List...
#
# End
# 100.0
#
# Teller_Ends_Service
# 117.97531750803793
#
# Customer_Departure
# 118.8449449146278
#
# Customer_Arrival
# 123.16393049066453
#
#
# Processing (and deleting) the event --  End -- at time  100.0
# End of simulation
# Printing the Events List...
#
# Events list is EMPTY

# %%
#my_list = ['a','b','c','d','e','f']
my_list = []

for letter in my_list:
    print(letter)
if my_list == []:
    print('EMPTY')
# Out:
# EMPTY
